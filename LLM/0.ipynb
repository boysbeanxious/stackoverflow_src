# %%
import sys, os
p = os.path.abspath('..')
# p = p+r'\config'
sys.path.insert(1, p)
import pandas as pd
import re
import numpy as np

path = './result'
file_list = os.listdir(path)

# %%
df = pd.DataFrame()
opt_file = [x for x in file_list if x.startswith(f'sc_')]

for f in opt_file:
    tmp = pd.read_csv(f'./result/{f}', index_col =0)
    df = pd.concat([df, tmp], axis =0)
# Out:
# ['c_result_2_10_Y_1.csv',
#  'l_result_3_10_Y_7_sys_prompt3.csv',
#  'c_result_3_10_Y_2.csv',
#  'l_result_2_10_Y_2_sys_prompt4.csv',
#  'sc_l_result_1_5_Y_5_sys_prompt4.csv',
#  'l_result_3_10_N_3_sys_prompt2.csv',
#  'l_result_2_10_N_3_sys_prompt4.csv',
#  'l_result_2_100_N_1.csv',
#  'l_result_3_10_Y_0_sys_prompt2.csv',
#  'sc_l_result_3_5_N_0_sys_prompt4.csv',
#  'l_result_1_10_Y_8_sys_prompt4.csv',
#  'sc_l_result_3_10_N_0_sys_prompt4.csv',
#  'l_result_3_10_N_2_sys_prompt3.csv',
#  'l_result_2_10_Y_9_sys_prompt2.csv',
#  'l_result_3_10_N_5_sys_prompt3.csv',
#  'l_result_1_10_N_0_sys_prompt3.csv',
#  'l_result_1_10_N_5_sys_prompt2.csv',
#  'c_result_3_10_Y_1.csv',
#  'l_result_1_10_N_4_sys_prompt1.csv',
#  'l_result_3_10_Y_7_sys_prompt2.csv',
#  'l_result_3_10_Y_4_sys_prompt1.csv',
#  'l_result_3_10_Y_3_sys_prompt3.csv',
#  'l_result_3_10_Y_4_sys_prompt4.csv',
#  'l_result_1_10_Y_9_sys_prompt1.csv',
#  'sc_l_result_3_10_Y_1_sys_prompt4.csv',
#  'l_result_3_10_Y_2.csv',
# ...
