# %%
# https://ppiazi.tistory.com/entry/python-cyclomatic-complexity-%EB%AA%A8%EB%93%88-lizard

# %%
# https://github.com/terryyin/lizard

# %%
# pip install cognitive_complexity

# %%
import sys, os
p = os.path.abspath('..')
pp = os.path.abspath('../..')
sys.path.insert(1, p)
sys.path.insert(1, pp)

# %%
#customized preprocessing pkg
import preprocess as pp
import pandas as pd
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# https://joaorafaelm.github.io/notebook/python/2021/04/10/cognitive-complexity.html
import config.config as conf
from lib.complexity import SrcBulkInsert as SB

# %%
input_year = '2021'

# %%
input_pl = 'java'

# %%
print(conf.DATA_PATH)
# Out:
# /usr/share/d_ollama

# %% [markdown]
# ### 소스코드 complexity 계산

# %%
# 파일 불러오기
with open(f'{conf.DATA_PATH}/data/complexity_{input_pl}_df_{input_year}.pkl', 'rb') as f:
    complexity_java_df = pickle.load(f)

# %%
complexity_java_df['cdate'].min()
# Out:
# '2021-01-01'

# %%
complexity_java_df['cdate'].max()
# Out:
# '2021-12-31'

# %%
htmlp = pp.HTMLParser()
codep = pp.CodeSectionParser()

# %%
complexity_java_df['c_h_body'] = complexity_java_df['body'].apply(lambda x : htmlp.clean_html_str(x))

# %%
complexity_java_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87544 entries, 0 to 87543
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        87544 non-null  int64
#  1   cdate     87544 non-null  object
#  2   title     87544 non-null  object
#  3   body      87544 non-null  object
#  4   c_h_body  87544 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.3+ MB

# %%
complexity_java_df['c_body'] = complexity_java_df['body'].apply(lambda x : codep(x))

# %%
complexity_java_df
# Out:
#              id       cdate  \
# 0      70542827  2021-12-31
# 1      70542869  2021-12-31
# 2      70542979  2021-12-31
# 3      70543231  2021-12-31
# 4      70543275  2021-12-31
# ...         ...         ...
# 87539  68096438  2021-06-23
# 87540  68096444  2021-06-23
# 87541  68096486  2021-06-23
# 87542  68096541  2021-06-23
# 87543  68096560  2021-06-23
#
#                                                    title  \
# 0      Can't make Admob App Open Ads to appear on app...
# 1        I cannot connect to the websocket using Postman
# 2                                Android convert charset
# 3      Spring cloud stream RabbitMQ - bind DLQ with a...
# 4      Execution failed for task ':app:checkDebugDupl...
# ...                                                  ...
# 87539  Java 8 LocalDate returns different date than i...
# 87540       Mapstruct Mapper with @ConfigProperty in JEE
# 87541  SQL Server query no longer slow after query ch...
# 87542       How to call this retrofit method every hour?
# 87543  Why does is the problem with the code below,My...
#
#                                                     body  \
# 0      <p>I'm trying to implement Admob App Open Ads ...
# 1      <p>I am trying to create a simple chat applica...
# 2      <p>How can I convert this &quot;Predajnďż˝&quo...
# 3      <p>I am using Spring Cloud Stream version <cod...
# 4      <h2>Task failed with an exception.</h2>\n<ul>\...
# ...                                                  ...
# 87539  <p>If the date in the database row is at least...
# 87540  <p>Hello good people of StackOverflow :)</p>\n...
# 87541  <p>I have the following query :</p>\n<pre><cod...
# 87542  <p>How do I call this method every hour since ...
# 87543  <p>This is My Code.This is Standalone java cla...
#
#                                                 c_h_body  \
# 0      I'm trying to implement Admob App Open Ads and...
# 1      I am trying to create a simple chat applicatio...
# 2      How can I convert this ";Predajnďż˝"; (Windows...
# 3      I am using Spring Cloud Stream version 3.0.6.R...
# 4      Task failed with an exception.\n\nWhat went wr...
# ...                                                  ...
# 87539  If the date in the database row is at least a ...
# 87540  Hello good people of StackOverflow :)\nI have ...
# 87541  I have the following query :\nSELECT\n  A.id,\...
# 87542  How do I call this method every hour since I a...
# 87543  This is My Code.This is Standalone java class ...
#
#                                                   c_body
# 0      {'code_sections': [{'off_beg': 443, 'off_end':...
# 1      {'code_sections': [{'off_beg': 263, 'off_end':...
# 2                                  {'code_sections': []}
# 3      {'code_sections': [{'off_beg': 728, 'off_end':...
# 4                                  {'code_sections': []}
# ...                                                  ...
# 87539                              {'code_sections': []}
# 87540  {'code_sections': [{'off_beg': 428, 'off_end':...
# 87541  {'code_sections': [{'off_beg': 47, 'off_end': ...
# 87542  {'code_sections': [{'off_beg': 459, 'off_end':...
# 87543  {'code_sections': [{'off_beg': 114, 'off_end':...
#
# [87544 rows x 6 columns]

# %%
complexity_java_src = complexity_java_df[['id', 'c_body']]

# %%
complexity_java_src['code_len'] = complexity_java_src['c_body'].apply(lambda x: len(x['code_sections']))
# Out:
# /tmp/ipykernel_2841317/804880781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complexity_java_src['code_len'] = complexity_java_src['c_body'].apply(lambda x: len(x['code_sections']))

# %%
complexity_java_src = complexity_java_src[complexity_java_src['code_len']>0]

# %%
complexity_java_src.head(5)
# Out:
#          id                                             c_body  code_len
# 0  70542827  {'code_sections': [{'off_beg': 443, 'off_end':...         2
# 1  70542869  {'code_sections': [{'off_beg': 263, 'off_end':...         5
# 3  70543231  {'code_sections': [{'off_beg': 728, 'off_end':...         2
# 5  70543352  {'code_sections': [{'off_beg': 189, 'off_end':...         2
# 6  70543706  {'code_sections': [{'off_beg': 72, 'off_end': ...         4

# %%
src_df = pd.DataFrame(columns = ['id', 'src'])
def code_explode(row) : 
    global src_df
    src_arr = []
    for i in range(row['code_len']):
        new_rows = pd.DataFrame({'id': [row['id']], 'src': [row['c_body']['code_sections'][i]['span_str']]})
        src_df = pd.concat([src_df, new_rows], axis=0)

    return True

# %%
# bert_src_ex = bert_src[['q_id', 'q_prep_text']].apply(pd.Series.explode)
complexity_java_src.apply(code_explode, axis = 1)
# Out:
# 0        True
# 1        True
# 3        True
# 5        True
# 6        True
#          ...
# 87538    True
# 87540    True
# 87541    True
# 87542    True
# 87543    True
# Length: 64231, dtype: bool

# %%
src_df.head()
# Out:
#          id                                                src
# 0  70542827  public class MyApplication extends Application...
# 0  70542827  /**\n * Prefetches App Open Ads.\n */\npublic ...
# 0  70542869  @Configuration\n@EnableWebSocketMessageBroker\...
# 0  70542869  @Controller\npublic class WebSocketController ...
# 0  70542869  @Builder\n@Getter\npublic class Message {\n   ...

# %%
src_df.reset_index(drop=True, inplace=True)

# %%
src_df.reset_index(inplace=True)

# %%
src_df.head()
# Out:
#    index        id                                                src
# 0      0  70542827  public class MyApplication extends Application...
# 1      1  70542827  /**\n * Prefetches App Open Ads.\n */\npublic ...
# 2      2  70542869  @Configuration\n@EnableWebSocketMessageBroker\...
# 3      3  70542869  @Controller\npublic class WebSocketController ...
# 4      4  70542869  @Builder\n@Getter\npublic class Message {\n   ...

# %%
src_df.iloc[0, 0]
src_df.iloc[0, 1]
# Out:
# 70542827

# %%
sbi = SB.SrcBulkInsert()
b_re = sbi.get_from_db(src_df.iloc[0, 0], src_df.iloc[0, 1])

if b_re==False :
   sbi.insert_posts_src(src_df)

# %%
for i in range(src_df.shape[0]):
    idx = src_df.iloc[i, 0]
    qid = src_df.iloc[i, 1]
    src = src_df.iloc[i, 2]
    file_nm = str(idx)+'_' + str(qid)+'.java'
    with open(f'{conf.DATA_PATH}/data/src/{input_year}_{input_pl}_src/{file_nm}', 'wb') as f:
        f.write(src.encode())

# %%
# https://github.com/rohaquinlop/complexipy

# %%
# pip install complexipy

# %%
# !complexipy /home/mghan/sopjt/git/data/src/3_74963438.py -l file -o

# %%
# cyclomatic은 모든 언어 가능 but cognitive는 언어별로 따로 분석해야함
# 하려면 소나큐브 사야 함 
# pyhon 기준으로는 조금 삽질하면 할 수 있을 듯.... 해보고 유의미하면 소나큐브 고?

# %% [markdown]
# ### complexity 결과 확인

# %%
path = f'{conf.DATA_PATH}/data/src/{input_year}_{input_pl}_excel/'
file_list = os.listdir(path)
file_list_csv = [file for file in file_list if file.endswith(".csv")]

# print ("file_list_csv: {}".format(file_list_csv))

# %%
calc_com_df = pd.DataFrame(columns = ['Absolute Module Path','Module Position',	'Module Declaration',	'Max nesting',	'Cognitive Complexity'])
for file_nm in file_list_csv :
    tmp = pd.read_csv(path+file_nm, sep=';')
    tmp['file_nm'] = file_nm
    calc_com_df = pd.concat([calc_com_df, tmp], axis = 0)

# %%
calc_com_df.head()
# Out:
#                 Absolute Module Path Module Position  \
# 0                         null.Hello               4
# 0  integration.com.foo.proj.StepDefs              13
# 1  integration.com.foo.proj.StepDefs              17
# 2  integration.com.foo.proj.StepDefs              21
# 0             null.QuestionVariables               8
#
#                                   Module Declaration Max nesting  \
# 0                                    Hello resolve()           1
# 0               void the_client_issues_GET_version()           1
# 1  void the_client_receives_status_code_of(int st...           1
# 2  void the_client_receives_server_version_body(S...           1
# 0                   ScreenOptions getScreenOptions()           1
#
#   Cognitive Complexity             file_nm
# 0                    0  94813_66957064.csv
# 0                    0  54822_68479587.csv
# 1                    0  54822_68479587.csv
# 2                    0  54822_68479587.csv
# 0                    0  93612_66993824.csv

# %%
# 전체 데이터셋 
with open(f'{conf.DATA_PATH}/data/calc_com_df_{input_year}_{input_pl}.pkl', 'wb') as f:
    pickle.dump(calc_com_df, f)

# %%
calc_com_df.head()
# Out:
#                 Absolute Module Path Module Position  \
# 0                         null.Hello               4
# 0  integration.com.foo.proj.StepDefs              13
# 1  integration.com.foo.proj.StepDefs              17
# 2  integration.com.foo.proj.StepDefs              21
# 0             null.QuestionVariables               8
#
#                                   Module Declaration Max nesting  \
# 0                                    Hello resolve()           1
# 0               void the_client_issues_GET_version()           1
# 1  void the_client_receives_status_code_of(int st...           1
# 2  void the_client_receives_server_version_body(S...           1
# 0                   ScreenOptions getScreenOptions()           1
#
#   Cognitive Complexity             file_nm
# 0                    0  94813_66957064.csv
# 0                    0  54822_68479587.csv
# 1                    0  54822_68479587.csv
# 2                    0  54822_68479587.csv
# 0                    0  93612_66993824.csv

# %%
calc_com_df.reset_index(drop=True, inplace=True)

# %%
calc_com_df.head()
# Out:
#                 Absolute Module Path Module Position  \
# 0                         null.Hello               4
# 1  integration.com.foo.proj.StepDefs              13
# 2  integration.com.foo.proj.StepDefs              17
# 3  integration.com.foo.proj.StepDefs              21
# 4             null.QuestionVariables               8
#
#                                   Module Declaration Max nesting  \
# 0                                    Hello resolve()           1
# 1               void the_client_issues_GET_version()           1
# 2  void the_client_receives_status_code_of(int st...           1
# 3  void the_client_receives_server_version_body(S...           1
# 4                   ScreenOptions getScreenOptions()           1
#
#   Cognitive Complexity             file_nm
# 0                    0  94813_66957064.csv
# 1                    0  54822_68479587.csv
# 2                    0  54822_68479587.csv
# 3                    0  54822_68479587.csv
# 4                    0  93612_66993824.csv

# %%
calc_com_df['index'] = calc_com_df['file_nm'].apply(lambda x : x.split('_')[0])
# calc_com_df['Path'].apply(lambda x : [  for i in x.split('_')])

# %%
calc_com_df['id'] = calc_com_df['file_nm'].apply(lambda x : x.split('_')[1].split('.')[0])

# %%
calc_com_df.sort_values(by = ['index', 'id'])
# Out:
#        Absolute Module Path Module Position  \
# 23385      null.CloudConfig              13
# 23386      null.CloudConfig              18
# 19417     null.PhoneNumbers               6
# 19418     null.PhoneNumbers              10
# 32105      null.UserServlet               6
# ...                     ...             ...
# 36040  null.PasswordEncoder               4
# 35403          null.DAOUser              14
# 35404          null.DAOUser              18
# 35405          null.DAOUser              22
# 35406          null.DAOUser              26
#
#                                       Module Declaration Max nesting  \
# 23385                        AmazonSNS amazonSnsClient()           1
# 23386            AWSCredentialsProvider aWSCredentials()           1
# 19417                                     PhoneNumbers()           1
# 19418                                  String toString()           1
# 32105  void doPost(HttpServletRequest request, HttpSe...           1
# ...                                                  ...         ...
# 36040      BCryptPasswordEncoder bCryptPasswordEncoder()           1
# 35403                               String getUsername()           1
# 35404                  void setUsername(String username)           1
# 35405                               String getPassword()           1
# 35406                  void setPassword(String password)           1
#
#       Cognitive Complexity              file_nm   index        id
# 23385                    0   10000_70100862.csv   10000  70100862
# 23386                    0   10000_70100862.csv   10000  70100862
# 19417                    0  100021_66762875.csv  100021  66762875
# 19418                    0  100021_66762875.csv  100021  66762875
# 32105                    0  100023_66762875.csv  100023  66762875
# ...                    ...                  ...     ...       ...
# 36040                    0   99983_66768741.csv   99983  66768741
# 35403                    0   99984_66768741.csv   99984  66768741
# 35404                    0   99984_66768741.csv   99984  66768741
# 35405                    0   99984_66768741.csv   99984  66768741
# 35406                    0   99984_66768741.csv   99984  66768741
#
# [36272 rows x 8 columns]

# %%
calc_com_df[['index', 'id', 'Cognitive Complexity']] = calc_com_df[['index', 'id', 'Cognitive Complexity']].astype('int')

# %%
src_df[['index', 'id']] = src_df[['index', 'id']].astype('int')

# %%
calc_com_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36272 entries, 0 to 36271
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Absolute Module Path  36272 non-null  object
#  1   Module Position       36272 non-null  object
#  2   Module Declaration    36272 non-null  object
#  3   Max nesting           36272 non-null  object
#  4   Cognitive Complexity  36272 non-null  int64
#  5   file_nm               36272 non-null  object
#  6   index                 36272 non-null  int64
#  7   id                    36272 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 2.2+ MB

# %%
calc_com_df.sort_values(by = ['index', 'id'])
# Out:
#            Absolute Module Path Module Position  \
# 22161      null.WebSocketConfig               5
# 22162      null.WebSocketConfig              11
# 13034  null.WebSocketController               3
# 34241       null.NotePlayerTest               9
# 25542      null.Login_Interface               4
# ...                         ...             ...
# 31747                 life.Main               4
# 34102               null.Client              21
# 34103               null.Client              25
# 34104               null.Client              53
# 17632                 hello.Foo               4
#
#                                       Module Declaration Max nesting  \
# 22161  void configureMessageBroker(MessageBrokerRegis...           1
# 22162  void registerStompEndpoints(StompEndpointRegis...           1
# 13034                OutputMessage send(Message message)           1
# 34241                           void main(String[] args)           1
# 25542                                  Login_Interface()           2
# ...                                                  ...         ...
# 31747                           void main(String[] args)           1
# 34102                                           Client()           1
# 34103                                void makeRequests()           4
# 34104                           void main(String[] args)           1
# 17632                                         void foo()           1
#
#        Cognitive Complexity              file_nm   index        id
# 22161                     0       2_70542869.csv       2  70542869
# 22162                     0       2_70542869.csv       2  70542869
# 13034                     0       3_70542869.csv       3  70542869
# 34241                     0      17_70543717.csv      17  70543717
# 25542                     1      18_70543723.csv      18  70543723
# ...                     ...                  ...     ...       ...
# 31747                     0  139624_68095022.csv  139624  68095022
# 34102                     0  139629_68095070.csv  139629  68095070
# 34103                     7  139629_68095070.csv  139629  68095070
# 34104                     0  139629_68095070.csv  139629  68095070
# 17632                     0  139660_68095816.csv  139660  68095816
#
# [36272 rows x 8 columns]

# %%
calc_com_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36272 entries, 0 to 36271
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Absolute Module Path  36272 non-null  object
#  1   Module Position       36272 non-null  object
#  2   Module Declaration    36272 non-null  object
#  3   Max nesting           36272 non-null  object
#  4   Cognitive Complexity  36272 non-null  int64
#  5   file_nm               36272 non-null  object
#  6   index                 36272 non-null  int64
#  7   id                    36272 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 2.2+ MB

# %%
src_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139701 entries, 0 to 139700
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   index   139701 non-null  int64
#  1   id      139701 non-null  int64
#  2   src     139701 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 3.2+ MB

# %%
calc_com_df = pd.merge(src_df,  calc_com_df, how = 'left', on = ['index', 'id'])

# %%
calc_com_df = pd.merge(complexity_java_df[['id', 'cdate']], calc_com_df, on = 'id')

# %%
calc_com_df.head()
# Out:
#          id       cdate  index  \
# 0  70542827  2021-12-31      0
# 1  70542827  2021-12-31      1
# 2  70542869  2021-12-31      2
# 3  70542869  2021-12-31      2
# 4  70542869  2021-12-31      3
#
#                                                  src  \
# 0  public class MyApplication extends Application...
# 1  /**\n * Prefetches App Open Ads.\n */\npublic ...
# 2  @Configuration\n@EnableWebSocketMessageBroker\...
# 3  @Configuration\n@EnableWebSocketMessageBroker\...
# 4  @Controller\npublic class WebSocketController ...
#
#        Absolute Module Path Module Position  \
# 0                       NaN             NaN
# 1                       NaN             NaN
# 2      null.WebSocketConfig               5
# 3      null.WebSocketConfig              11
# 4  null.WebSocketController               3
#
#                                   Module Declaration Max nesting  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  void configureMessageBroker(MessageBrokerRegis...           1
# 3  void registerStompEndpoints(StompEndpointRegis...           1
# 4                OutputMessage send(Message message)           1
#
#    Cognitive Complexity         file_nm
# 0                   NaN             NaN
# 1                   NaN             NaN
# 2                   0.0  2_70542869.csv
# 3                   0.0  2_70542869.csv
# 4                   0.0  3_70542869.csv

# %%
# 일자별로 아예 소스가 수행되지 않는 건 
calc_com_df_back = calc_com_df.copy()
calc_ed_com_df = calc_com_df[~calc_com_df['file_nm'].isna()]

# %%
calc_ed_com_df = calc_ed_com_df.sort_values(by = ['cdate', 'id', 'Cognitive Complexity'], ascending = [True, True, False]).groupby('id').head(1)

# %%
calc_ed_com_df.head()
# Out:
#               id       cdate   index  \
# 155034  65526451  2021-01-01  133000
# 155048  65526838  2021-01-01  133008
# 155056  65526932  2021-01-01  133015
# 155075  65527073  2021-01-01  133017
# 155077  65527151  2021-01-01  133019
#
#                                                       src  \
# 155034  public class BankInfo {\n    private String na...
# 155048  public abstract class Place {\n    private Str...
# 155056  public class Data {\n    private String eventn...
# 155075  public class MainActivity extends AppCompatAct...
# 155077  public final class ClientToken implements Reme...
#
#        Absolute Module Path Module Position  \
# 155034        null.BankInfo               4
# 155048           null.Place               8
# 155056            null.Data              11
# 155075    null.MainActivity              44
# 155077     null.ClientToken              13
#
#                                        Module Declaration Max nesting  \
# 155034                                   String getName()           1
# 155048                                  void showEvents()           1
# 155056                              String getEventname()           1
# 155075                      boolean onSupportNavigateUp()           1
# 155077  ClientToken(final String clientName, final Cre...           1
#
#         Cognitive Complexity              file_nm
# 155034                   0.0  133000_65526451.csv
# 155048                   0.0  133008_65526838.csv
# 155056                   0.0  133015_65526932.csv
# 155075                   1.0  133017_65527073.csv
# 155077                   0.0  133019_65527151.csv

# %%
calc_ed_com_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10057 entries, 155034 to 55
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10057 non-null  int64
#  1   cdate                 10057 non-null  object
#  2   index                 10057 non-null  int64
#  3   src                   10057 non-null  object
#  4   Absolute Module Path  10057 non-null  object
#  5   Module Position       10057 non-null  object
#  6   Module Declaration    10057 non-null  object
#  7   Max nesting           10057 non-null  object
#  8   Cognitive Complexity  10057 non-null  float64
#  9   file_nm               10057 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 864.3+ KB

# %%
calc_ed_com_df = calc_ed_com_df.groupby('cdate').mean(numeric_only=True)[['Cognitive Complexity']].reset_index()

# %%
calc_ed_com_df.head()
# Out:
#         cdate  Cognitive Complexity
# 0  2021-01-01              1.500000
# 1  2021-01-02              0.392857
# 2  2021-01-03              0.372093
# 3  2021-01-04              1.454545
# 4  2021-01-05              0.321429

# %%
calc_ed_com_box_df = calc_ed_com_df.copy()

# %%
calc_ed_com_box_df['yyyymm'] = calc_ed_com_box_df['cdate'].str[:7]

# %%
ym_list = calc_ed_com_box_df['yyyymm'].unique()

# %%
[calc_ed_com_box_df[calc_ed_com_box_df['yyyymm']==x]  for x in ym_list]
# Out:
# [         cdate  Cognitive Complexity   yyyymm
#  0   2021-01-01              1.500000  2021-01
#  1   2021-01-02              0.392857  2021-01
#  2   2021-01-03              0.372093  2021-01
#  3   2021-01-04              1.454545  2021-01
#  4   2021-01-05              0.321429  2021-01
#  5   2021-01-06              0.516129  2021-01
#  6   2021-01-07              0.625000  2021-01
#  7   2021-01-08              0.767442  2021-01
#  8   2021-01-09              0.833333  2021-01
#  9   2021-01-10              1.260870  2021-01
#  10  2021-01-11              1.564103  2021-01
#  11  2021-01-12              0.354839  2021-01
#  12  2021-01-13              0.333333  2021-01
#  13  2021-01-14              0.566667  2021-01
#  14  2021-01-15              0.275000  2021-01
#  15  2021-01-16              1.150000  2021-01
#  16  2021-01-17              0.684211  2021-01
#  17  2021-01-18              1.026316  2021-01
#  18  2021-01-19              0.525000  2021-01
#  19  2021-01-20              1.000000  2021-01
#  20  2021-01-21              1.676471  2021-01
#  21  2021-01-22              1.033333  2021-01
#  22  2021-01-23              0.526316  2021-01
#  23  2021-01-24              0.500000  2021-01
#  24  2021-01-25              0.864865  2021-01
#  25  2021-01-26              1.343750  2021-01
#  26  2021-01-27              0.823529  2021-01
#  27  2021-01-28              0.500000  2021-01
#  28  2021-01-29              1.135135  2021-01
#  29  2021-01-30              0.478261  2021-01
#  30  2021-01-31              0.428571  2021-01,
#           cdate  Cognitive Complexity   yyyymm
#  31  2021-02-01              1.236842  2021-02
#  32  2021-02-02              1.233333  2021-02
#  33  2021-02-03              0.724138  2021-02
#  34  2021-02-04              0.678571  2021-02
#  35  2021-02-05              1.846154  2021-02
#  36  2021-02-06              1.062500  2021-02
#  37  2021-02-07              0.450000  2021-02
#  38  2021-02-08              1.235294  2021-02
#  39  2021-02-09              0.794118  2021-02
#  40  2021-02-10              0.684211  2021-02
#  41  2021-02-11              0.580645  2021-02
#  42  2021-02-12              0.857143  2021-02
#  43  2021-02-13              1.517241  2021-02
#  44  2021-02-14              0.875000  2021-02
#  45  2021-02-15              1.875000  2021-02
#  46  2021-02-16              0.558824  2021-02
#  47  2021-02-17              0.764706  2021-02
#  48  2021-02-18              0.645833  2021-02
#  49  2021-02-19              1.000000  2021-02
#  50  2021-02-20              1.133333  2021-02
#  51  2021-02-21              0.384615  2021-02
#  52  2021-02-22              0.685714  2021-02
#  53  2021-02-23              1.100000  2021-02
#  54  2021-02-24              0.421053  2021-02
#  55  2021-02-25              2.026316  2021-02
#  56  2021-02-26              0.513514  2021-02
#  57  2021-02-27              0.520000  2021-02
#  332  2021-11-29              0.304348  2021-11
#  333  2021-11-30              0.400000  2021-11,
#            cdate  Cognitive Complexity   yyyymm
#  334  2021-12-01              1.000000  2021-12
#  335  2021-12-02              0.607143  2021-12
#  336  2021-12-03              1.041667  2021-12
#  337  2021-12-04              1.714286  2021-12
#  338  2021-12-05              1.000000  2021-12
#  339  2021-12-06              0.909091  2021-12
#  340  2021-12-07              0.370370  2021-12
#  341  2021-12-08              1.444444  2021-12
#  342  2021-12-09              0.904762  2021-12
#  343  2021-12-10              0.739130  2021-12
#  344  2021-12-11              0.600000  2021-12
#  345  2021-12-12              0.666667  2021-12
#  346  2021-12-13              1.105263  2021-12
#  347  2021-12-14              1.242424  2021-12
#  348  2021-12-15              1.285714  2021-12
#  349  2021-12-16              0.958333  2021-12
#  350  2021-12-17              0.086957  2021-12
#  351  2021-12-18              1.947368  2021-12
#  352  2021-12-19              1.000000  2021-12
#  353  2021-12-20              0.444444  2021-12
#  354  2021-12-21              0.478261  2021-12
#  355  2021-12-22              0.720000  2021-12
#  356  2021-12-23              0.666667  2021-12
#  357  2021-12-24              0.125000  2021-12
#  358  2021-12-25              1.583333  2021-12
#  359  2021-12-26              0.588235  2021-12
#  360  2021-12-27              0.814815  2021-12
#  361  2021-12-28              0.375000  2021-12
#  362  2021-12-29              0.705882  2021-12
#  363  2021-12-30              0.866667  2021-12
#  364  2021-12-31              0.533333  2021-12]

# %%
sharey = True ## 또는 sharey=False
sharex = True ## 또는 sharex=False

fig, axs = plt.subplots(1, 2, figsize = (20, 5), sharey=sharey, sharex=sharex)
# plt.xticks(rotation=45)
# major_xticks = ['2013-11-30','2014-11-30','2015-11-30','2016-11-30','2017-11-30','2018-11-30','2019-11-30','2020-11-30'
#                 ,'2021-11-30', '2022-11-30', '2023-11-30']
# yticks = np.arange(200, 2000, 400)
axs[0].bar(calc_ed_com_df['cdate']
        ,  calc_ed_com_df['Cognitive Complexity']
        ,  color = 'skyblue'
        # ,  edgecolor = 'black'
      ) # hist type

axs[0].set_title('Number of Questions over time', fontsize = 15)
axs[0].set_xlabel('Date', fontsize = 15)
axs[0].set_ylabel('# of Q', fontsize = 15)
# axs[0].set_xticks(major_xticks)
# axs[0].set_yticks(yticks)
# axs[0].axvline([major_xticks[-2]], # add vertical line
#            color = 'blue',
#            linestyle = '--',
#            linewidth = 1.5)
axs[0].tick_params(axis='x', rotation=45)
# axs[0].yticks(yt)

axs[0].bar(calc_ed_com_df['cdate']
        ,  calc_ed_com_df['Cognitive Complexity']
        ,  color = 'skyblue'
        # ,  edgecolor = 'black'
      ) # hist type

axs[1].set_title('Number of Answers over time', fontsize = 15)
axs[1].set_xlabel('Date', fontsize = 15)
axs[1].set_ylabel('# of A', fontsize = 15)
# axs[1].set_xticks(major_xticks)
# axs[1].set_yticks(yticks)
# axs[1].axvline([major_xticks[-2]], # add vertical line
#            color = 'blue',
#            linestyle = '--',
#            linewidth = 1.5)
axs[1].tick_params(axis='x', rotation=45)

plt.show();

# %%
sharey = True ## 또는 sharey=False
sharex = True ## 또는 sharex=False

fig, axs = plt.subplots(1, 2, figsize = (20, 5), sharey=False, sharex=False)
# plt.xticks(rotation=45)
major_xticks = ['2022-01-30','2022-02-28','2022-03-30','2022-04-30','2022-05-30','2022-06-30','2022-07-30','2022-08-30','2022-09-30','2022-10-30','2022-11-30','2022-12-30',
                '2023-01-30','2023-02-28','2023-03-30','2023-04-30','2023-05-30','2023-06-30','2023-07-30','2023-08-30','2023-09-30','2023-10-30','2023-11-30','2023-12-30']
axs1_xticks = ym_list
axs1_xticks = np.insert(axs1_xticks, 0, '0')  # 인덱스 2 위치에 100을 추가 
# yticks = np.arange(200, 2000, 400)
axs[0].bar(calc_ed_com_df['cdate']
        ,  calc_ed_com_df['Cognitive Complexity']
        ,  color = 'skyblue'
        # ,  edgecolor = 'black'
      ) # hist type

axs[0].set_title('Avg Cognitive Complexity per Day', fontsize = 15)
axs[0].set_xlabel('Date', fontsize = 15)
axs[0].set_ylabel('Avg Cognitive Complexity', fontsize = 15)
axs[0].set_xticks(major_xticks)
# axs[0].set_yticks(yticks)
# axs[0].axvline([major_xticks[-2]], # add vertical line
#            color = 'blue',
#            linestyle = '--',
#            linewidth = 1.5)
axs[0].tick_params(axis='x', rotation=45)
# axs[0].yticks(yt)

axs[1].boxplot([calc_ed_com_box_df.loc[calc_ed_com_box_df['yyyymm']==x, 'Cognitive Complexity']  for x in ym_list]
        # ,  edgecolor = 'black'
      ) # hist type

axs[1].set_title('Cognitive Complexity per Month', fontsize = 15)
axs[1].set_xlabel('Date', fontsize = 15)
axs[1].set_ylabel('Cognitive Complexity', fontsize = 15)
axs[1].set_xticks(range(len(axs1_xticks)), axs1_xticks)
# axs[1].set_yticks(yticks)
# axs[1].axvline([major_xticks[-2]], # add vertical line
#            color = 'blue',
#            linestyle = '--',
#            linewidth = 1.5)
axs[1].tick_params(axis='x', rotation=45)

plt.show();

# %%
ym_list[:11]
# ym_list[12:]
# Out:
# array(['2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06',
#        '2021-07', '2021-08', '2021-09', '2021-10', '2021-11'],
#       dtype=object)

# %%
sharey = True ## 또는 sharey=False
sharex = True ## 또는 sharex=False

fig, axs = plt.subplots(2, 1, figsize = (10, 10), sharey=True, sharex=False)
# plt.xticks(rotation=45)

axs0_xticks = ym_list[:11]
axs0_xticks = np.insert(axs0_xticks, 0, '0')  # 인덱스 2 위치에 100을 추가 

axs1_xticks = ym_list[12:]
axs1_xticks = np.insert(axs1_xticks, 0, '0')  # 인덱스 2 위치에 100을 추가 
yticks = np.arange(0.5, 5, 0.5)

axs[0].boxplot([calc_ed_com_box_df.loc[calc_ed_com_box_df['yyyymm']==x, 'Cognitive Complexity']  for x in ym_list[:11]]
        # ,  edgecolor = 'black'
      ) # hist type

axs[0].set_title('Cognitive Complexity per Month', fontsize = 15)
axs[0].set_xlabel('Date', fontsize = 15)
axs[0].set_ylabel('Cognitive Complexity', fontsize = 15)
axs[0].set_xticks(range(len(axs0_xticks)), axs0_xticks)
axs[0].set_yticks(yticks)
# axs[1].axvline([major_xticks[-2]], # add vertical line
#            color = 'blue',
#            linestyle = '--',
#            linewidth = 1.5)
axs[0].tick_params(axis='x', rotation=45)


axs[1].boxplot([calc_ed_com_box_df.loc[calc_ed_com_box_df['yyyymm']==x, 'Cognitive Complexity']  for x in ym_list[12:]]
        # ,  edgecolor = 'black'
      ) # hist type

axs[1].set_title('Cognitive Complexity per Month', fontsize = 15)
axs[1].set_xlabel('Date', fontsize = 15)
axs[1].set_ylabel('Cognitive Complexity', fontsize = 15)
axs[1].set_xticks(range(len(axs1_xticks)), axs1_xticks)
axs[1].set_yticks(yticks)
# axs[1].axvline([major_xticks[-2]], # add vertical line
#            color = 'blue',
#            linestyle = '--',
#            linewidth = 1.5)
axs[1].tick_params(axis='x', rotation=45)
plt.tight_layout()    
plt.show();

# %%
len(np.arange(2, 13, 1))
# Out:
# 11

# %%
sharey = True ## 또는 sharey=False
sharex = True ## 또는 sharex=False

fig, axs = plt.subplots(2, 1, figsize = (10, 10), sharey=True, sharex=False)
# plt.xticks(rotation=45)

axs0_xticks = ym_list[:11]
axs0_xticks = np.insert(axs0_xticks, 0, '0')  # 인덱스 2 위치에 100을 추가 

axs1_xticks = ym_list[12:]
axs1_xticks = np.insert(axs1_xticks, 0, '0')  # 인덱스 2 위치에 100을 추가 
yticks = np.arange(0.5, 5, 0.5)


axs[0].violinplot([calc_ed_com_box_df.loc[calc_ed_com_box_df['yyyymm']==x, 'Cognitive Complexity']  for x in ym_list[:11]], positions=np.arange(1, 12, 1))
axs[0].set_title('Cognitive Complexity per Month', fontsize = 15)
axs[0].set_xlabel('Date', fontsize = 15)
axs[0].set_ylabel('Cognitive Complexity', fontsize = 15)
axs[0].set_xticks(range(len(axs0_xticks)), axs0_xticks)
axs[0].set_yticks(yticks)
# axs[1].axvline([major_xticks[-2]], # add vertical line
#            color = 'blue',
#            linestyle = '--',
#            linewidth = 1.5)
axs[0].tick_params(axis='x', rotation=45)



axs[1].violinplot([calc_ed_com_box_df.loc[calc_ed_com_box_df['yyyymm']==x, 'Cognitive Complexity']  for x in ym_list[12:]], positions=np.arange(1, 12, 1))
axs[1].set_title('Cognitive Complexity per Month', fontsize = 15)
axs[1].set_xlabel('Date', fontsize = 15)
axs[1].set_ylabel('Cognitive Complexity', fontsize = 15)
axs[1].set_xticks(range(len(axs1_xticks)), axs1_xticks)
axs[1].set_yticks(yticks)
# axs[1].axvline([major_xticks[-2]], # add vertical line
#            color = 'blue',
#            linestyle = '--',
#            linewidth = 1.5)
axs[1].tick_params(axis='x', rotation=45)
plt.tight_layout()    
plt.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 29
#      21 # axs[1].axvline([major_xticks[-2]], # add vertical line
#      22 #            color = 'blue',
#      23 #            linestyle = '--',
#      24 #            linewidth = 1.5)
#      25 axs[0].tick_params(axis='x', rotation=45)
# ---> 29 axs[1].violinplot([calc_ed_com_box_df.loc[calc_ed_com_box_df['yyyymm']==x, 'Cognitive Complexity']  for x in ym_list[12:]], positions=np.arange(1, 12, 1))
#      30 axs[1].set_title('Cognitive Complexity per Month', fontsize = 15)
#      31 axs[1].set_xlabel('Date', fontsize = 15)
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:1416, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1413 @functools.wraps(func)
#    1414 def inner(ax, *args, data=None, **kwargs):
#    1415     if data is None:
# -> 1416         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1418     bound = new_sig.bind(ax, *args, **kwargs)
#    1419     auto_label = (bound.arguments.get(label_namer)
#    1420                   or bound.kwargs.get(label_namer))
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:7942, in Axes.violinplot(self, dataset, positions, vert, widths, showmeans, showextrema, showmedians, quantiles, points, bw_method)
#    7939     kde = mlab.GaussianKDE(X, bw_method)
#    7940     return kde.evaluate(coords)
# -> 7942 vpstats = cbook.violin_stats(dataset, _kde_method, points=points,
#    7943                              quantiles=quantiles)
#    7944 return self.violin(vpstats, positions=positions, vert=vert,
#    7945                    widths=widths, showmeans=showmeans,
#    7946                    showextrema=showextrema, showmedians=showmedians)
#
# File /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1485, in violin_stats(X, method, points, quantiles)
#    1482 stats = {}
#    1484 # Calculate basic stats for the distribution
# -> 1485 min_val = np.min(x)
#    1486 max_val = np.max(x)
#    1487 quantile_val = np.percentile(x, 100 * q)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2953, in min(a, axis, out, keepdims, initial, where)
#    2836 @array_function_dispatch(_min_dispatcher)
#    2837 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2838         where=np._NoValue):
#    2839     """
#    2840     Return the minimum of an array or minimum along an axis.
#    2841
#    (...)
#    2951     6
#    2952     """
# -> 2953     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2954                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity
